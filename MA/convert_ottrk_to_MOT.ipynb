# %%
# %reset -f

import sys
import os
import bz2
import csv
import pandas as pd
import ast
# import json
import ujson
import numpy

from scripts.convertfunctions import ottrk_to_mot as otm

otm(filename= '2024-03-29_20-00-00_MOT20-01',
    directory='Z:/04_Daten/MOT20/train/MOT20-01')

otm(filename= '2024-03-29_20-00-00_MOT20-02',
    directory='Z:/04_Daten/MOT20/train/MOT20-02')

otm(filename= '2024-03-29_20-00-00_MOT20-03',
    directory='Z:/04_Daten/MOT20/train/MOT20-03')

otm(filename= '2024-03-29_20-00-00_MOT20-05',
    directory='Z:/04_Daten/MOT20/train/MOT20-05')
# Out:
# 2024-03-29_20-00-00_MOT20-01 wird konvertiert...
# Export nach Z:/04_Daten/MOT20/train/MOT20-01/det/
# 2024-03-29_20-00-00_MOT20-02 wird konvertiert...
# Export nach Z:/04_Daten/MOT20/train/MOT20-02/det/
# 2024-03-29_20-00-00_MOT20-03 wird konvertiert...
# Export nach Z:/04_Daten/MOT20/train/MOT20-03/det/
# 2024-03-29_20-00-00_MOT20-05 wird konvertiert...
# Export nach Z:/04_Daten/MOT20/train/MOT20-05/det/
#         frame  track-id            x           y           h           w  \
# 0           1         1  1260.900208  836.696777  243.303223  104.820190
# 1           1         2   754.885834  446.474442  173.785980   78.042297
# 2           1         3   242.244072  166.904610  140.877914   52.990250
# 3           1         4   852.953033  888.451630  182.865051   93.190369
# 4           1         5  1024.106079  911.304932  168.695068   80.423340
# ...       ...       ...          ...         ...         ...         ...
# ...
